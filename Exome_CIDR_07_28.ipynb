# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.cm as cm
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.backends.backend_pdf

col_names = ['chrom','start','end','svtype','cn','nsnp','startsnp', 'endsnp', 'conf', 'iid','common_sv','mask_pass','pli_gene', 'max_pli', 'REC_gene', 'max_REC','n_genes', 'genes','n_pli' , 'pli','n_rec','rec','nsnp_less_than_7']

df5 = pd.read_csv(r'C:\Users\aqngu\Desktop\Gleeson_Lab\Exome_Negative_CIDR\Results\cidr_2017_2018_stitched_nsnpfil_cnpflagged_maskpass_burden.tsv' , sep='\t', header=None, skiprows=1, names=col_names)


df5.head()
# Out:
#    chrom   start      end svtype  cn  nsnp   startsnp     endsnp        conf  \
# 0      1  752721  1179816    DUP   3   248  rs3131972    exm2001   41.800375
# 1      1  752721  5722405    DEL   1  1392  rs3131972   rs770721  555.092813
# 2      1  752721  5722405    DEL   1  1485  rs3131972   rs770721  462.402625
# 3      1  752721   846808    DEL   1     5  rs3131972  rs4475691   15.323000
# 4      1  752721   846808    DUP   3     5  rs3131972  rs4475691   10.946000
#
#                                                  iid  ...     max_pli  \
# 0  WG3002051-DNAF06-P2097-S649_4340_6_1-1-0224061976  ...  5.4727e-07
# 1  WG3002809-DNAC01-P2211-S649_5738_5_4-1-1163278483  ...     0.99999
# 2  WG3002809-DNAC02-P2211-S649_5738_5_5-1-1163278491  ...     0.99999
# 3  WG3002055-DNAD03-P2097-S649_5035_5_2-1-0224134284  ...           .
# 4  WG3002054-DNAD02-P2097-S649_2757_4_1-1-0224134475  ...           .
#
#    REC_gene  max_REC n_genes  \
# 0      AGRN      1.0      14
# ...

# %%
df5["mask_pass"] = df5["mask_pass"].astype(str)
df5["nsnp_less_than_7"] = df5["nsnp_less_than_7"].astype(str)
df6 = df5[(df5.nsnp_less_than_7 == 'False') & (df5.mask_pass == 'True')]

# %%
df6["n_genes"] = df6["n_genes"].astype(str)
df6["svtype"] = df6["svtype"].astype(str)
df7 = df6[(df6.svtype == 'DEL') & (df6.n_genes != '.')]
# Out:
# C:\Users\aqngu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\aqngu\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df7["n_genes"] = df7["n_genes"].astype(float)
#df7['n_genes'].sum()
#df7['n_genes'].mean()
#df7['n_genes'].median()
#df7['n_genes'].quantile(.25)
#df7['n_genes'].min()
#df7['n_genes'].max()
# Out:
# C:\Users\aqngu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
sns.set(style="whitegrid")
f, ax = plt.subplots(1,1,figsize=(5,5))

df7["n_genes"] = df7["n_genes"].astype(float)
df7['n_genes_log'] = np.log10(df7['n_genes'])

ax = sns.stripplot(x='n_genes', y='conf', data=df7) 
ax.set(xlabel = "n_genes")
f.tight_layout()
f.savefig(r"C:\Users\aqngu\Desktop\Gleeson_Lab\Exome_Negative_CIDR\Results\stripplot_ngenes_confidence.png")
# Out:
# C:\Users\aqngu\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\aqngu\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
df6["n_genes"] = df6["n_genes"].astype(str)
df6["svtype"] = df6["svtype"].astype(str)
df8 = df6[(df6.cn == 0) & (df6.n_genes != '.')]
df8["n_genes"] = df8["n_genes"].astype(float)
df8['n_genes'].sum()
#df8['cn'].head(50)
#df8['n_genes'].head(50)
# Out:
# C:\Users\aqngu\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\aqngu\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
sns.set(style="whitegrid")
f, ax = plt.subplots(1,1,figsize=(5,5))

#df8["n_genes"] = df8["n_genes"].astype(float)
#df8['n_genes_log'] = np.log10(df8['n_genes'])

ax = sns.pointplot(x='n_genes', y='conf', data=df8) 
ax.set(xlabel = "n_genes")
f.tight_layout()
f.savefig(r"C:\Users\aqngu\Desktop\Gleeson_Lab\Exome_Negative_CIDR\Results\pointplot_ngenes_confidence.png")

# %%
#df8['n_genes'].sum()
#df8['n_genes'].mean()
#df8['n_genes'].median()
#df8['n_genes'].quantile(.25)
#df8['n_genes'].min()
#df8['n_genes'].max()

# %%
df9 = df7[(df7.max_REC != '.') & (df7.max_REC != '.')]
df9["max_pli"] = df9["max_pli"].astype(float)
df9["max_REC"] = df9["max_REC"].astype(float)
df9['pli/pREC'] = (df9['max_pli']/df9['max_REC'])
#df9['max_REC'].head(50)

# %%
f, ax = plt.subplots(1,1,figsize=(5,5))
df9['pli/pREC_log'] = np.log10(df9['pli/pREC'])
ax.hist(x=df9["pli/pREC_log"], bins=100)
ax.set_xlabel('pli/pREC_confidence_log')
ax.set_ylabel('frequency')
f.savefig(r"C:\Users\aqngu\Desktop\Gleeson_Lab\Exome_Negative_CIDR\Results\hist_plipREC_confidence_log.png")

# %%
#df9['pli/pREC'].sum()
#df9['pli/pREC'].mean()
#df9['pli/pREC'].median()
#df9['pli/pREC'].quantile(.25)
#df9['pli/pREC'].min()
#df9['pli/pREC'].max()

# %%
df9["max_REC"] = df9["max_REC"].astype(float)
df10 = df9[(df9.cn == 0) & (df9.max_REC > 0.9)]
#df10['max_REC'].head(40)
df10["n_genes"] = df10["n_genes"].astype(float)
#df10['n_genes'].sum()
# Out:
# C:\Users\aqngu\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
#df10['pli/pREC'].sum()
#df10['n_genes'].mean()
#df10['n_genes'].median()
#df10['n_genes'].quantile(.75)
#df10['n_genes'].min()
#df10['n_genes'].max()

# %%
sns.set(style="whitegrid")
f, ax = plt.subplots(1,1,figsize=(5,5))

#df10["n_genes"] = df10["n_genes"].astype(float)
#df10['n_genes_log'] = np.log10(df10['n_genes'])

ax = sns.pointplot(x='n_genes', y='conf', data=df10) 
ax.set(xlabel = "n_genes")
f.tight_layout()
f.savefig(r"C:\Users\aqngu\Desktop\Gleeson_Lab\Exome_Negative_CIDR\Results\pointplot_ngenes_confidence_cn0_RECgreater.9.png")

# %%
df9["max_REC"] = df9["max_REC"].astype(float)
df11 = df9[(df9.cn == 0)]

# %%
sns.set(style="whitegrid")
f, ax = plt.subplots(1,1,figsize=(5,5))

#df11["max_pli"] = df11["max_pli"].astype(float)
#df11['max_pli_log'] = np.log10(df11['max_pli'])

ax = sns.stripplot(y='max_REC', x='max_pli', data=df11) 
#ax.set(xlabel = "n_genes")
f.tight_layout()
f.savefig(r"C:\Users\aqngu\Desktop\Gleeson_Lab\Exome_Negative_CIDR\Results\stripplot_maxREC_maxpli.png")
# Out:
# C:\Users\aqngu\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# C:\Users\aqngu\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
sns.set(style="whitegrid")
f, ax = plt.subplots(1,1,figsize=(5,5))

#df10["max_pli"] = df10["max_pli"].astype(float)
#df10['max_pli_log'] = np.log10(df10['max_pli'])

ax = sns.stripplot(y='max_REC', x='max_pli', data=df10) 
#ax.set(xlabel = "n_genes")
f.tight_layout()
f.savefig(r"C:\Users\aqngu\Desktop\Gleeson_Lab\Exome_Negative_CIDR\Results\stripplot_maxRECgreater.9_maxpli.png")
